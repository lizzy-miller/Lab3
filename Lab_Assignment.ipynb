# %% [markdown]
# ## GitHub
# https://github.com/lizzy-miller/Lab3

# %% [markdown]
# ### a

# %%
import pandas as pd
import numpy as np
import requests
import os
import psycopg2
import zipfile
import io
from sqlalchemy import create_engine

# %%
POSTGRES_PASSWORD = os.getenv('POSTGRES_PASSWORD')

# %% [markdown]
# ### b

# %%
url ='https://databank.worldbank.org/data/download/ESG_CSV.zip'
r = requests.get(url)
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall()

# %%
url = 'https://v-dem.net/media/datasets/V-Dem-CY-Core_csv_v13.zip'
r = requests.get(url)
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall()

# %%
vdem = pd.read_csv('V-Dem-CY-Core-v13.csv')
wb = pd.read_csv('ESGData.csv')
country = pd.read_csv('ESGCountry.csv')

# %% [markdown]
# ### C. V-Dem

# %%
vdem_clean = vdem[['country_text_id', 'country_name', 'year', 'v2x_polyarchy']]

# %%
vdem_clean = vdem_clean.query("year >= 1960 and year <= 2021")

# %%
vdem_clean = vdem_clean.rename({'country_text_id': 'country_code',
                               'country_name': 'country_name_vdem',
                               'v2x_polyarchy':'democracy'}, axis = 1)

# %%
vdem_clean = vdem_clean.sort_values(by = ['country_code', 'year'])

# %%
vdem_clean.head(10)
# Out:
#      country_code country_name_vdem  year  democracy
# 5433          AFG       Afghanistan  1960      0.080
# 5434          AFG       Afghanistan  1961      0.083
# 5435          AFG       Afghanistan  1962      0.082
# 5436          AFG       Afghanistan  1963      0.085
# 5437          AFG       Afghanistan  1964      0.137
# 5438          AFG       Afghanistan  1965      0.150
# 5439          AFG       Afghanistan  1966      0.161
# 5440          AFG       Afghanistan  1967      0.163
# 5441          AFG       Afghanistan  1968      0.163
# 5442          AFG       Afghanistan  1969      0.162

# %% [markdown]
# ### D. ESG Country

# %%
country_clean = country[['Country Code', 'Table Name', 'Long Name', 'Currency Unit', 'Region', 'Income Group']]

# %%
country_clean = country_clean.rename({'Country Code': 'country_code',
                                     'Table Name': 'country_name_wb',
                                     'Long Name': 'country_longname', 
                                      'Currency Unit': 'currency_unit', 
                                      'Region': 'region', 
                                      'Income Group': 'income_group'}, axis = 1)

# %%
noncountries = ["Arab World", "Central Europe and the Baltics",
 "Caribbean small states",
 "East Asia & Pacific (excluding high income)",
 "Early-demographic dividend","East Asia & Pacific",
 "Europe & Central Asia (excluding high income)",
 "Europe & Central Asia", "Euro area",
 "European Union","Fragile and conflict affected situations",
 "High income",
 "Heavily indebted poor countries (HIPC)","IBRD only",
 "IDA & IBRD total",
 "IDA total","IDA blend","IDA only",
 "Latin America & Caribbean (excluding high income)",
 "Latin America & Caribbean",
 "Least developed countries: UN classification",
 "Low income","Lower middle income","Low & middle income",
 "Late-demographic dividend","Middle East & North Africa",
 "Middle income",
 "Middle East & North Africa (excluding high income)",
 "North America","OECD members",
 "Other small states","Pre-demographic dividend",
 "Pacific island small states",
 "Post-demographic dividend",
 "Sub-Saharan Africa (excluding high income)",
                "Sub-Saharan Africa",
 "Small states","East Asia & Pacific (IDA & IBRD)",
 "Europe & Central Asia (IDA & IBRD)",
 "Latin America & Caribbean (IDA & IBRD)",
 "Middle East & North Africa (IDA & IBRD)","South Asia",
 "South Asia (IDA & IBRD)",
 "Sub-Saharan Africa (IDA & IBRD)",
 "Upper middle income", "World"]

# %%
country_clean = country_clean.query('country_name_wb not in @noncountries')

# %%
country_clean.head(10)
# Out:
#    country_code       country_name_wb              country_longname  \
# 0           AFG           Afghanistan  Islamic State of Afghanistan
# 1           AGO                Angola   People's Republic of Angola
# 2           ALB               Albania           Republic of Albania
# 3           AND               Andorra       Principality of Andorra
# 5           ARE  United Arab Emirates          United Arab Emirates
# 6           ARG             Argentina            Argentine Republic
# 7           ARM               Armenia           Republic of Armenia
# 8           ATG   Antigua and Barbuda           Antigua and Barbuda
# 9           AUS             Australia     Commonwealth of Australia
# 10          AUT               Austria           Republic of Austria
#
#             currency_unit                      region         income_group
# 0          Afghan afghani                  South Asia           Low income
# 1          Angolan kwanza          Sub-Saharan Africa  Lower middle income
# 2            Albanian lek       Europe & Central Asia  Upper middle income
# 3                    Euro       Europe & Central Asia          High income
# 5           U.A.E. dirham  Middle East & North Africa          High income
# 6          Argentine peso   Latin America & Caribbean  Upper middle income
# 7           Armenian dram       Europe & Central Asia  Upper middle income
# 8   East Caribbean dollar   Latin America & Caribbean          High income
# 9       Australian dollar         East Asia & Pacific          High income
# 10                   Euro       Europe & Central Asia          High income

# %% [markdown]
# ### E. World Bank ESG Data

# %%
wb_clean = wb[['Country Code', 'Country Name', 'Indicator Code'] + [col for col in wb.columns if col.startswith('19') or col.startswith('20')]]

# %%
wb_clean = wb_clean.rename({'Country Code': 'country_code',
                           'Country Name': 'country_name_wb', 
                           'Indicator Code': 'feature'}, axis = 1)

# %%
noncountries.remove('World')

# %%
wb_clean = wb_clean.query('country_name_wb not in @noncountries')

# %%
replace_map = {
 "AG.LND.AGRI.ZS": "agricultural_land",
 "AG.LND.FRST.ZS": "forest_area",
 "AG.PRD.FOOD.XD": "food_production_index",
 "CC.EST": "control_of_corruption",
 "EG.CFT.ACCS.ZS": "access_to_clean_fuels_and_technologies_for_cooking",
 "EG.EGY.PRIM.PP.KD": "energy_intensity_level_of_primary_energy",
 "EG.ELC.ACCS.ZS": "access_to_electricity",
 "EG.ELC.COAL.ZS": "electricity_production_from_coal_sources",
 "EG.ELC.RNEW.ZS": "renewable_electricity_output",
 "EG.FEC.RNEW.ZS": "renewable_energy_consumption",
 "EG.IMP.CONS.ZS": "energy_imports",
 "EG.USE.COMM.FO.ZS": "fossil_fuel_energy_consumption",
 "EG.USE.PCAP.KG.OE": "energy_use",
 "EN.ATM.CO2E.PC": "co2_emissions",
 "EN.ATM.METH.PC": "methane_emissions",
 "EN.ATM.NOXE.PC": "nitrous_oxide_emissions",
 "EN.ATM.PM25.MC.M3": "pm2_5_air_pollution",
 "EN.CLC.CDDY.XD": "cooling_degree_days",
 "EN.CLC.GHGR.MT.CE": "ghg_net_emissions",
 "EN.CLC.HEAT.XD": "heat_index_35",
 "EN.CLC.MDAT.ZS": "droughts",
 "EN.CLC.PRCP.XD": "maximum_5-day_rainfall",
 "EN.CLC.SPEI.XD": "mean_drought_index","EN.MAM.THRD.NO": "mammal_species",
 "EN.POP.DNST": "population_density",
 "ER.H2O.FWTL.ZS": "annual_freshwater_withdrawals",
 "ER.PTD.TOTL.ZS": "terrestrial_and_marine_protected_areas",
 "GB.XPD.RSDV.GD.ZS": "research_and_development_expenditure",
 "GE.EST": "government_effectiveness",
 "IC.BUS.EASE.XQ": "ease_of_doing_business_rank",
 "IC.LGL.CRED.XQ": "strength_of_legal_rights_index",
 "IP.JRN.ARTC.SC": "scientific_and_technical_journal_articles",
 "IP.PAT.RESD": "patent_applications",
 "IT.NET.USER.ZS": "individuals_using_the_internet",
 "NV.AGR.TOTL.ZS": "agriculture",
 "NY.ADJ.DFOR.GN.ZS": "net_forest_depletion",
 "NY.ADJ.DRES.GN.ZS": "natural_resources_depletion",
 "NY.GDP.MKTP.KD.ZG": "gdp_growth",
 "PV.EST": "political_stability_and_absence_of_violence",
 "RL.EST": "rule_of_law",
 "RQ.EST": "regulatory_quality",
 "SE.ADT.LITR.ZS": "literacy_rate",
 "SE.ENR.PRSC.FM.ZS": "gross_school_enrollment",
 "SE.PRM.ENRR": "primary_school_enrollment",
 "SE.XPD.TOTL.GB.ZS": "government_expenditure_on_education",
 "SG.GEN.PARL.ZS": "proportion_of_seats_held_by_women_in_national_parliament",
 "SH.DTH.COMM.ZS": "cause_of_death",
 "SH.DYN.MORT": "mortality_rate",
 "SH.H2O.SMDW.ZS": "people_using_safely_managed_drinking_water_services",
 "SH.MED.BEDS.ZS": "hospital_beds",
 "SH.STA.OWAD.ZS": "prevalence_of_overweight",
 "SH.STA.SMSS.ZS": "people_using_safely_managed_sanitation_services",
 "SI.DST.FRST.20": "income_share_held_by_lowest_20pct",
 "SI.POV.GINI": "gini_index",
 "SI.POV.NAHC": "poverty_headcount_ratio_at_national_poverty_lines",
 "SI.SPR.PCAP.ZG": "annualized_average_growth_rate_in_per_capita_real_surve",
 "SL.TLF.0714.ZS": "children_in_employment",
 "SL.TLF.ACTI.ZS": "labor_force_participation_rate",
 "SL.TLF.CACT.FM.ZS": "ratio_of_female_to_male_labor_force_participation_ra",
 "SL.UEM.TOTL.ZS": "unemployment",
 "SM.POP.NETM": "net_migration",
 "SN.ITK.DEFC.ZS": "prevalence_of_undernourishment",
 "SP.DYN.LE00.IN": "life_expectancy_at_birth",
 "SP.DYN.TFRT.IN": "fertility_rate",
 "SP.POP.65UP.TO.ZS": "population_ages_65_and_above",
 "SP.UWT.TFRT": "unmet_need_for_contraception",
 "VA.EST": "voice_and_accountability",
 "EN.CLC.CSTP.ZS": "coastal_protection",
 "SD.ESR.PERF.XQ": "economic_and_social_rights_performance_score",
 "EN.CLC.HDDY.XD": "heating_degree_days",
 "EN.LND.LTMP.DC": "land_surface_temperature",
 "ER.H2O.FWST.ZS": "freshwater_withdrawal",
 "EN.H2O.BDYS.ZS": "water_quality",
 "AG.LND.FRLS.HA": "tree_cover_loss",
}

# %%
wb_clean['feature'] = wb_clean['feature'].map(replace_map)

# %%
wb_clean = pd.melt(wb_clean, id_vars = ['country_code', 'country_name_wb', 'feature'], value_vars = [str(i) for i in range(1960, 2023)])

# %%
wb_clean = wb_clean.rename({'variable' : 'year'}, axis = 1)

# %%
wb_clean = wb_clean.pivot(index=['country_code', 'country_name_wb', 'year'],
                                  columns='feature', values='value').reset_index()

# %% [markdown]
# G

# %%
wb_clean['year'] = wb_clean['year'].astype(int)
wb_clean
# Out:
# feature country_code country_name_wb  year  \
# 0                AFG     Afghanistan  1960
# 1                AFG     Afghanistan  1961
# 2                AFG     Afghanistan  1962
# 3                AFG     Afghanistan  1963
# 4                AFG     Afghanistan  1964
# ...              ...             ...   ...
# 12217            ZWE        Zimbabwe  2018
# 12218            ZWE        Zimbabwe  2019
# 12219            ZWE        Zimbabwe  2020
# 12220            ZWE        Zimbabwe  2021
# 12221            ZWE        Zimbabwe  2022
#
# feature  access_to_clean_fuels_and_technologies_for_cooking  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 12217                                                 30.0
# 12218                                                 30.2
# 12219                                                 30.3
# 12220                                                 30.3
# 12221                                                  NaN
#
# feature  access_to_electricity  agricultural_land  agriculture  \
# 0                          NaN                NaN          NaN
# 1                          NaN          57.878356          NaN
# 2                          NaN          57.955016          NaN
# 3                          NaN          58.031676          NaN
# 4                          NaN          58.116002          NaN
# ...                        ...                ...          ...
# 12217                45.400288          41.876696     7.319375
# 12218                46.682095          41.876696     9.819262
# 12219                52.747667          41.876696     8.772859
# 12220                48.979927          41.876696     8.849899
# 12221                      NaN                NaN          NaN
#
# feature  annual_freshwater_withdrawals  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 12217                        30.761677
# 12218                        30.761677
# 12219                        30.761677
# 12220                              NaN
# 12221                              NaN
#
# feature  annualized_average_growth_rate_in_per_capita_real_surve  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 12217                                                  NaN
# 12218                                                  NaN
# 12219                                                  NaN
# 12220                                                  NaN
# 12221                                                  NaN
#
# feature  cause_of_death  ...  research_and_development_expenditure  \
# 0                   NaN  ...                                   NaN
# 1                   NaN  ...                                   NaN
# 2                   NaN  ...                                   NaN
# 3                   NaN  ...                                   NaN
# 4                   NaN  ...                                   NaN
# ...                 ...  ...                                   ...
# 12217               NaN  ...                                   NaN
# 12218         47.647301  ...                                   NaN
# 12219               NaN  ...                                   NaN
# 12220               NaN  ...                                   NaN
# 12221               NaN  ...                                   NaN
#
# feature  rule_of_law  scientific_and_technical_journal_articles  \
# 0                NaN                                        NaN
# 1                NaN                                        NaN
# 2                NaN                                        NaN
# 3                NaN                                        NaN
# 4                NaN                                        NaN
# ...              ...                                        ...
# 12217      -1.292463                                     406.23
# 12218      -1.303515                                     431.62
# 12219      -1.329611                                     480.16
# 12220      -1.277202                                        NaN
# 12221      -1.236284                                        NaN
#
# feature  strength_of_legal_rights_index  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 12217                               5.0
# 12218                               6.0
# 12219                               NaN
# 12220                               NaN
# 12221                               NaN
#
# feature  terrestrial_and_marine_protected_areas  tree_cover_loss  \
# 0                                           NaN              NaN
# 1                                           NaN              NaN
# 2                                           NaN              NaN
# 3                                           NaN              NaN
# 4                                           NaN              NaN
# ...                                         ...              ...
# 12217                                 27.214585              NaN
# 12218                                 27.214747              NaN
# 12219                                 27.214747              NaN
# 12220                                 27.214747              NaN
# 12221                                 27.214747              NaN
#
# feature  unemployment  unmet_need_for_contraception  voice_and_accountability  \
# 0                 NaN                           NaN                       NaN
# 1                 NaN                           NaN                       NaN
# 2                 NaN                           NaN                       NaN
# 3                 NaN                           NaN                       NaN
# 4                 NaN                           NaN                       NaN
# ...               ...                           ...                       ...
# 12217           6.784                           NaN                 -1.136798
# 12218           7.370                           NaN                 -1.163669
# 12219           7.898                           NaN                 -1.113408
# 12220           8.067                           NaN                 -1.135830
# 12221           7.945                           NaN                 -1.102206
#
# feature  water_quality
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 12217              NaN
# 12218              NaN
# 12219             83.3
# 12220              NaN
# 12221              NaN
#
# [12222 rows x 74 columns]

# %% [markdown]
# H.

# %%
whole_world_data = wb_clean[wb_clean['country_name_wb'] == 'World'].copy()

# %%
whole_world_data.head(10).T
# Out:
#                                                     11844  11845  11846  \
# feature
# country_code                                          WLD    WLD    WLD
# country_name_wb                                     World  World  World
# year                                                 1960   1961   1962
# access_to_clean_fuels_and_technologies_for_cooking    NaN    NaN    NaN
# access_to_electricity                                 NaN    NaN    NaN
# ...                                                   ...    ...    ...
# tree_cover_loss                                       NaN    NaN    NaN
# unemployment                                          NaN    NaN    NaN
# unmet_need_for_contraception                          NaN    NaN    NaN
# voice_and_accountability                              NaN    NaN    NaN
# water_quality                                         NaN    NaN    NaN
#
#                                                     11847  11848  11849  \
# feature
# country_code                                          WLD    WLD    WLD
# country_name_wb                                     World  World  World
# year                                                 1963   1964   1965
# access_to_clean_fuels_and_technologies_for_cooking    NaN    NaN    NaN
# access_to_electricity                                 NaN    NaN    NaN
# ...                                                   ...    ...    ...
# tree_cover_loss                                       NaN    NaN    NaN
# unemployment                                          NaN    NaN    NaN
# unmet_need_for_contraception                          NaN    NaN    NaN
# voice_and_accountability                              NaN    NaN    NaN
# water_quality                                         NaN    NaN    NaN
#
#                                                     11850  11851  11852  11853
# feature
# country_code                                          WLD    WLD    WLD    WLD
# country_name_wb                                     World  World  World  World
# year                                                 1966   1967   1968   1969
# access_to_clean_fuels_and_technologies_for_cooking    NaN    NaN    NaN    NaN
# access_to_electricity                                 NaN    NaN    NaN    NaN
# ...                                                   ...    ...    ...    ...
# tree_cover_loss                                       NaN    NaN    NaN    NaN
# unemployment                                          NaN    NaN    NaN    NaN
# unmet_need_for_contraception                          NaN    NaN    NaN    NaN
# voice_and_accountability                              NaN    NaN    NaN    NaN
# water_quality                                         NaN    NaN    NaN    NaN
#
# [74 rows x 10 columns]

# %%
wb_clean = wb_clean.query("country_name_wb != 'World'")
wb_clean.head(10)
# Out:
# feature country_code country_name_wb  year  \
# 0                AFG     Afghanistan  1960
# 1                AFG     Afghanistan  1961
# 2                AFG     Afghanistan  1962
# 3                AFG     Afghanistan  1963
# 4                AFG     Afghanistan  1964
# 5                AFG     Afghanistan  1965
# 6                AFG     Afghanistan  1966
# 7                AFG     Afghanistan  1967
# 8                AFG     Afghanistan  1968
# 9                AFG     Afghanistan  1969
#
# feature  access_to_clean_fuels_and_technologies_for_cooking  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# 6                                                      NaN
# 7                                                      NaN
# 8                                                      NaN
# 9                                                      NaN
#
# feature  access_to_electricity  agricultural_land  agriculture  \
# 0                          NaN                NaN          NaN
# 1                          NaN          57.878356          NaN
# 2                          NaN          57.955016          NaN
# 3                          NaN          58.031676          NaN
# 4                          NaN          58.116002          NaN
# 5                          NaN          58.123668          NaN
# 6                          NaN          58.192662          NaN
# 7                          NaN          58.229459          NaN
# 8                          NaN          58.230992          NaN
# 9                          NaN          58.255523          NaN
#
# feature  annual_freshwater_withdrawals  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# 6                                  NaN
# 7                                  NaN
# 8                                  NaN
# 9                                  NaN
#
# feature  annualized_average_growth_rate_in_per_capita_real_surve  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# 6                                                      NaN
# 7                                                      NaN
# 8                                                      NaN
# 9                                                      NaN
#
# feature  cause_of_death  ...  research_and_development_expenditure  \
# 0                   NaN  ...                                   NaN
# 1                   NaN  ...                                   NaN
# 2                   NaN  ...                                   NaN
# 3                   NaN  ...                                   NaN
# 4                   NaN  ...                                   NaN
# 5                   NaN  ...                                   NaN
# 6                   NaN  ...                                   NaN
# 7                   NaN  ...                                   NaN
# 8                   NaN  ...                                   NaN
# 9                   NaN  ...                                   NaN
#
# feature  rule_of_law  scientific_and_technical_journal_articles  \
# 0                NaN                                        NaN
# 1                NaN                                        NaN
# 2                NaN                                        NaN
# 3                NaN                                        NaN
# 4                NaN                                        NaN
# 5                NaN                                        NaN
# 6                NaN                                        NaN
# 7                NaN                                        NaN
# 8                NaN                                        NaN
# 9                NaN                                        NaN
#
# feature  strength_of_legal_rights_index  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                                   NaN
#
# feature  terrestrial_and_marine_protected_areas  tree_cover_loss  \
# 0                                           NaN              NaN
# 1                                           NaN              NaN
# 2                                           NaN              NaN
# 3                                           NaN              NaN
# 4                                           NaN              NaN
# 5                                           NaN              NaN
# 6                                           NaN              NaN
# 7                                           NaN              NaN
# 8                                           NaN              NaN
# 9                                           NaN              NaN
#
# feature  unemployment  unmet_need_for_contraception  voice_and_accountability  \
# 0                 NaN                           NaN                       NaN
# 1                 NaN                           NaN                       NaN
# 2                 NaN                           NaN                       NaN
# 3                 NaN                           NaN                       NaN
# 4                 NaN                           NaN                       NaN
# 5                 NaN                           NaN                       NaN
# 6                 NaN                           NaN                       NaN
# 7                 NaN                           NaN                       NaN
# 8                 NaN                           NaN                       NaN
# 9                 NaN                           NaN                       NaN
#
# feature  water_quality
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
#
# [10 rows x 74 columns]

# %%
whole_world_data = whole_world_data.drop(['country_code', 'country_name_wb'], axis = 1)

# %%
whole_world_data.columns
# Out:
# Index(['year', 'access_to_clean_fuels_and_technologies_for_cooking',
#        'access_to_electricity', 'agricultural_land', 'agriculture',
#        'annual_freshwater_withdrawals',
#        'annualized_average_growth_rate_in_per_capita_real_surve',
#        'cause_of_death', 'children_in_employment', 'co2_emissions',
#        'coastal_protection', 'control_of_corruption', 'cooling_degree_days',
#        'economic_and_social_rights_performance_score',
#        'electricity_production_from_coal_sources', 'energy_imports',
#        'energy_intensity_level_of_primary_energy', 'energy_use',
#        'fertility_rate', 'food_production_index', 'forest_area',
#        'fossil_fuel_energy_consumption', 'freshwater_withdrawal', 'gdp_growth',
#        'ghg_net_emissions', 'gini_index', 'government_effectiveness',
#        'government_expenditure_on_education', 'gross_school_enrollment',
#        'heat_index_35', 'heating_degree_days', 'hospital_beds',
#        'income_share_held_by_lowest_20pct', 'individuals_using_the_internet',
#        'labor_force_participation_rate', 'land_surface_temperature',
#        'life_expectancy_at_birth', 'literacy_rate', 'mammal_species',
#        'mean_drought_index', 'methane_emissions', 'mortality_rate',
#        'natural_resources_depletion', 'net_forest_depletion', 'net_migration',
#        'nitrous_oxide_emissions', 'patent_applications',
#        'people_using_safely_managed_drinking_water_services',
#        'people_using_safely_managed_sanitation_services',
#        'pm2_5_air_pollution', 'political_stability_and_absence_of_violence',
#        'population_ages_65_and_above', 'population_density',
#        'poverty_headcount_ratio_at_national_poverty_lines',
#        'prevalence_of_overweight', 'prevalence_of_undernourishment',
#        'primary_school_enrollment',
#        'proportion_of_seats_held_by_women_in_national_parliament',
#        'ratio_of_female_to_male_labor_force_participation_ra',
#        'regulatory_quality', 'renewable_electricity_output',
#        'renewable_energy_consumption', 'research_and_development_expenditure',
#        'rule_of_law', 'scientific_and_technical_journal_articles',
#        'strength_of_legal_rights_index',
#        'terrestrial_and_marine_protected_areas', 'tree_cover_loss',
#        'unemployment', 'unmet_need_for_contraception',
#        'voice_and_accountability', 'water_quality'],
#       dtype='object', name='feature')

# %%
new_column_names = {col: f"world_{col}" for col in whole_world_data.columns if col != 'year'}
whole_world_data_clean = whole_world_data.rename(columns=new_column_names)
whole_world_data_clean['year'] = whole_world_data_clean['year'].astype(int)
whole_world_data_clean
# Out:
# feature  year  world_access_to_clean_fuels_and_technologies_for_cooking  \
# 11844    1960                                                NaN
# 11845    1961                                                NaN
# 11846    1962                                                NaN
# 11847    1963                                                NaN
# 11848    1964                                                NaN
# ...       ...                                                ...
# 11902    2018                                          67.696517
# 11903    2019                                          68.921601
# 11904    2020                                          70.184805
# 11905    2021                                          71.331487
# 11906    2022                                                NaN
#
# feature  world_access_to_electricity  world_agricultural_land  \
# 11844                            NaN                      NaN
# 11845                            NaN                35.879317
# 11846                            NaN                35.952470
# 11847                            NaN                36.035383
# 11848                            NaN                36.117043
# ...                              ...                      ...
# 11902                      89.893733                36.738458
# 11903                      90.194716                36.762648
# 11904                      90.483629                36.730920
# 11905                      91.413941                36.841665
# 11906                            NaN                      NaN
#
# feature  world_agriculture  world_annual_freshwater_withdrawals  \
# 11844                  NaN                                  NaN
# 11845                  NaN                                  NaN
# 11846                  NaN                                  NaN
# 11847                  NaN                                  NaN
# 11848                  NaN                                  NaN
# ...                    ...                                  ...
# 11902             3.951747                             9.137864
# 11903             4.013242                             9.167900
# 11904             4.352489                             9.109511
# 11905             4.304093                                  NaN
# 11906             4.329327                                  NaN
#
# feature  world_annualized_average_growth_rate_in_per_capita_real_surve  \
# 11844                                                  NaN
# 11845                                                  NaN
# 11846                                                  NaN
# 11847                                                  NaN
# 11848                                                  NaN
# ...                                                    ...
# 11902                                                  NaN
# 11903                                                  NaN
# 11904                                                  NaN
# 11905                                                  NaN
# 11906                                                  NaN
#
# feature  world_cause_of_death  world_children_in_employment  \
# 11844                     NaN                           NaN
# 11845                     NaN                           NaN
# 11846                     NaN                           NaN
# 11847                     NaN                           NaN
# 11848                     NaN                           NaN
# ...                       ...                           ...
# 11902                     NaN                           NaN
# 11903                18.40885                           NaN
# 11904                     NaN                           NaN
# 11905                     NaN                           NaN
# 11906                     NaN                           NaN
#
# feature  world_co2_emissions  ...  world_research_and_development_expenditure  \
# 11844                    NaN  ...                                         NaN
# 11845                    NaN  ...                                         NaN
# 11846                    NaN  ...                                         NaN
# 11847                    NaN  ...                                         NaN
# 11848                    NaN  ...                                         NaN
# ...                      ...  ...                                         ...
# 11902               4.641294  ...                                    2.196050
# 11903               4.582036  ...                                    2.331934
# 11904               4.291853  ...                                    2.627081
# 11905                    NaN  ...                                         NaN
# 11906                    NaN  ...                                         NaN
#
# feature  world_rule_of_law  world_scientific_and_technical_journal_articles  \
# 11844                  NaN                                              NaN
# 11845                  NaN                                              NaN
# 11846                  NaN                                              NaN
# 11847                  NaN                                              NaN
# 11848                  NaN                                              NaN
# ...                    ...                                              ...
# 11902                  NaN                                     2.565871e+06
# 11903                  NaN                                     2.734962e+06
# 11904                  NaN                                     2.933011e+06
# 11905                  NaN                                              NaN
# 11906                  NaN                                              NaN
#
# feature  world_strength_of_legal_rights_index  \
# 11844                                     NaN
# 11845                                     NaN
# 11846                                     NaN
# 11847                                     NaN
# 11848                                     NaN
# ...                                       ...
# 11902                                5.507853
# 11903                                5.685864
# 11904                                     NaN
# 11905                                     NaN
# 11906                                     NaN
#
# feature  world_terrestrial_and_marine_protected_areas  world_tree_cover_loss  \
# 11844                                             NaN                    NaN
# 11845                                             NaN                    NaN
# 11846                                             NaN                    NaN
# 11847                                             NaN                    NaN
# 11848                                             NaN                    NaN
# ...                                               ...                    ...
# 11902                                       14.337515                    NaN
# 11903                                       14.599801                    NaN
# 11904                                       14.787111                    NaN
# 11905                                       14.552260                    NaN
# 11906                                             NaN                    NaN
#
# feature  world_unemployment  world_unmet_need_for_contraception  \
# 11844                   NaN                                 NaN
# 11845                   NaN                                 NaN
# 11846                   NaN                                 NaN
# 11847                   NaN                                 NaN
# 11848                   NaN                                 NaN
# ...                     ...                                 ...
# 11902              5.699076                                 NaN
# 11903              5.543161                                 NaN
# 11904              6.898273                                 NaN
# 11905              6.201871                                 NaN
# 11906              5.772710                                 NaN
#
# feature  world_voice_and_accountability  world_water_quality
# 11844                               NaN                  NaN
# 11845                               NaN                  NaN
# 11846                               NaN                  NaN
# 11847                               NaN                  NaN
# 11848                               NaN                  NaN
# ...                                 ...                  ...
# 11902                               NaN                  NaN
# 11903                               NaN                  NaN
# 11904                               NaN                  NaN
# 11905                               NaN                  NaN
# 11906                               NaN                  NaN
#
# [63 rows x 72 columns]

# %% [markdown]
# i

# %%
vdem_clean
# Out:
#       country_code country_name_vdem  year  democracy
# 5433           AFG       Afghanistan  1960      0.080
# 5434           AFG       Afghanistan  1961      0.083
# 5435           AFG       Afghanistan  1962      0.082
# 5436           AFG       Afghanistan  1963      0.085
# 5437           AFG       Afghanistan  1964      0.137
# ...            ...               ...   ...        ...
# 26150          ZZB          Zanzibar  2017      0.267
# 26151          ZZB          Zanzibar  2018      0.268
# 26152          ZZB          Zanzibar  2019      0.266
# 26153          ZZB          Zanzibar  2020      0.258
# 26154          ZZB          Zanzibar  2021      0.276
#
# [10371 rows x 4 columns]

# %%
wb_clean.head(10)
# Out:
# feature country_code country_name_wb  year  \
# 0                AFG     Afghanistan  1960
# 1                AFG     Afghanistan  1961
# 2                AFG     Afghanistan  1962
# 3                AFG     Afghanistan  1963
# 4                AFG     Afghanistan  1964
# 5                AFG     Afghanistan  1965
# 6                AFG     Afghanistan  1966
# 7                AFG     Afghanistan  1967
# 8                AFG     Afghanistan  1968
# 9                AFG     Afghanistan  1969
#
# feature  access_to_clean_fuels_and_technologies_for_cooking  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# 6                                                      NaN
# 7                                                      NaN
# 8                                                      NaN
# 9                                                      NaN
#
# feature  access_to_electricity  agricultural_land  agriculture  \
# 0                          NaN                NaN          NaN
# 1                          NaN          57.878356          NaN
# 2                          NaN          57.955016          NaN
# 3                          NaN          58.031676          NaN
# 4                          NaN          58.116002          NaN
# 5                          NaN          58.123668          NaN
# 6                          NaN          58.192662          NaN
# 7                          NaN          58.229459          NaN
# 8                          NaN          58.230992          NaN
# 9                          NaN          58.255523          NaN
#
# feature  annual_freshwater_withdrawals  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# 6                                  NaN
# 7                                  NaN
# 8                                  NaN
# 9                                  NaN
#
# feature  annualized_average_growth_rate_in_per_capita_real_surve  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# 6                                                      NaN
# 7                                                      NaN
# 8                                                      NaN
# 9                                                      NaN
#
# feature  cause_of_death  ...  research_and_development_expenditure  \
# 0                   NaN  ...                                   NaN
# 1                   NaN  ...                                   NaN
# 2                   NaN  ...                                   NaN
# 3                   NaN  ...                                   NaN
# 4                   NaN  ...                                   NaN
# 5                   NaN  ...                                   NaN
# 6                   NaN  ...                                   NaN
# 7                   NaN  ...                                   NaN
# 8                   NaN  ...                                   NaN
# 9                   NaN  ...                                   NaN
#
# feature  rule_of_law  scientific_and_technical_journal_articles  \
# 0                NaN                                        NaN
# 1                NaN                                        NaN
# 2                NaN                                        NaN
# 3                NaN                                        NaN
# 4                NaN                                        NaN
# 5                NaN                                        NaN
# 6                NaN                                        NaN
# 7                NaN                                        NaN
# 8                NaN                                        NaN
# 9                NaN                                        NaN
#
# feature  strength_of_legal_rights_index  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                                   NaN
#
# feature  terrestrial_and_marine_protected_areas  tree_cover_loss  \
# 0                                           NaN              NaN
# 1                                           NaN              NaN
# 2                                           NaN              NaN
# 3                                           NaN              NaN
# 4                                           NaN              NaN
# 5                                           NaN              NaN
# 6                                           NaN              NaN
# 7                                           NaN              NaN
# 8                                           NaN              NaN
# 9                                           NaN              NaN
#
# feature  unemployment  unmet_need_for_contraception  voice_and_accountability  \
# 0                 NaN                           NaN                       NaN
# 1                 NaN                           NaN                       NaN
# 2                 NaN                           NaN                       NaN
# 3                 NaN                           NaN                       NaN
# 4                 NaN                           NaN                       NaN
# 5                 NaN                           NaN                       NaN
# 6                 NaN                           NaN                       NaN
# 7                 NaN                           NaN                       NaN
# 8                 NaN                           NaN                       NaN
# 9                 NaN                           NaN                       NaN
#
# feature  water_quality
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
#
# [10 rows x 74 columns]

# %% [markdown]
# ## I.
# Originally, I thought that this would a one-to-one merge because it seems that both data frames contain the same information with regard to country_code and year. To test this, I did an outer-merge and tested it with the 'indicator' to see how many are left-only, how many are right-only, and how many are one-to-one. I saw that there were numerous rows that were right only and numerous that were left only.

# %%
merged_df = pd.merge(wb_clean, vdem_clean, on=['country_code', 'year'], how='outer', indicator=True)
merged_df
# Out:
#       country_code country_name_wb  year  \
# 0              AFG     Afghanistan  1960
# 1              AFG     Afghanistan  1961
# 2              AFG     Afghanistan  1962
# 3              AFG     Afghanistan  1963
# 4              AFG     Afghanistan  1964
# ...            ...             ...   ...
# 12549          ZZB             NaN  2017
# 12550          ZZB             NaN  2018
# 12551          ZZB             NaN  2019
# 12552          ZZB             NaN  2020
# 12553          ZZB             NaN  2021
#
#        access_to_clean_fuels_and_technologies_for_cooking  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 12549                                                NaN
# 12550                                                NaN
# 12551                                                NaN
# 12552                                                NaN
# 12553                                                NaN
#
#        access_to_electricity  agricultural_land  agriculture  \
# 0                        NaN                NaN          NaN
# 1                        NaN          57.878356          NaN
# 2                        NaN          57.955016          NaN
# 3                        NaN          58.031676          NaN
# 4                        NaN          58.116002          NaN
# ...                      ...                ...          ...
# 12549                    NaN                NaN          NaN
# 12550                    NaN                NaN          NaN
# 12551                    NaN                NaN          NaN
# 12552                    NaN                NaN          NaN
# 12553                    NaN                NaN          NaN
#
#        annual_freshwater_withdrawals  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 12549                            NaN
# 12550                            NaN
# 12551                            NaN
# 12552                            NaN
# 12553                            NaN
#
#        annualized_average_growth_rate_in_per_capita_real_surve  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 12549                                                NaN
# 12550                                                NaN
# 12551                                                NaN
# 12552                                                NaN
# 12553                                                NaN
#
#        cause_of_death  ...  strength_of_legal_rights_index  \
# 0                 NaN  ...                             NaN
# 1                 NaN  ...                             NaN
# 2                 NaN  ...                             NaN
# 3                 NaN  ...                             NaN
# 4                 NaN  ...                             NaN
# ...               ...  ...                             ...
# 12549             NaN  ...                             NaN
# 12550             NaN  ...                             NaN
# 12551             NaN  ...                             NaN
# 12552             NaN  ...                             NaN
# 12553             NaN  ...                             NaN
#
#        terrestrial_and_marine_protected_areas  tree_cover_loss  unemployment  \
# 0                                         NaN              NaN           NaN
# 1                                         NaN              NaN           NaN
# 2                                         NaN              NaN           NaN
# 3                                         NaN              NaN           NaN
# 4                                         NaN              NaN           NaN
# ...                                       ...              ...           ...
# 12549                                     NaN              NaN           NaN
# 12550                                     NaN              NaN           NaN
# 12551                                     NaN              NaN           NaN
# 12552                                     NaN              NaN           NaN
# 12553                                     NaN              NaN           NaN
#
#        unmet_need_for_contraception  voice_and_accountability  water_quality  \
# 0                               NaN                       NaN            NaN
# 1                               NaN                       NaN            NaN
# 2                               NaN                       NaN            NaN
# 3                               NaN                       NaN            NaN
# 4                               NaN                       NaN            NaN
# ...                             ...                       ...            ...
# 12549                           NaN                       NaN            NaN
# 12550                           NaN                       NaN            NaN
# 12551                           NaN                       NaN            NaN
# 12552                           NaN                       NaN            NaN
# 12553                           NaN                       NaN            NaN
#
#        country_name_vdem  democracy      _merge
# 0            Afghanistan      0.080        both
# 1            Afghanistan      0.083        both
# 2            Afghanistan      0.082        both
# 3            Afghanistan      0.085        both
# 4            Afghanistan      0.137        both
# ...                  ...        ...         ...
# 12549           Zanzibar      0.267  right_only
# 12550           Zanzibar      0.268  right_only
# 12551           Zanzibar      0.266  right_only
# 12552           Zanzibar      0.258  right_only
# 12553           Zanzibar      0.276  right_only
#
# [12554 rows x 77 columns]

# %%
print(merged_df['_merge'].value_counts())
# Out:
# _merge
# both          9976
# left_only     2183
# right_only     395
# Name: count, dtype: int64

# %%
left_only = merged_df.query("_merge == 'left_only'")
left_only_years = left_only.groupby(['country_code', 'country_name_wb'])['year'].agg(['min', 'max'])
left_only_years.iloc[150:200]
# Out:
#                                               min   max
# country_code country_name_wb
# SEN          Senegal                         2022  2022
# SGP          Singapore                       2022  2022
# SLB          Solomon Islands                 2022  2022
# SLE          Sierra Leone                    2022  2022
# SLV          El Salvador                     2022  2022
# SMR          San Marino                      1960  2022
# SOM          Somalia                         2022  2022
# SRB          Serbia                          2022  2022
# SSD          South Sudan                     1960  2022
# STP          Sao Tome and Principe           2022  2022
# SUR          Suriname                        2022  2022
# SVK          Slovak Republic                 1960  2022
# SVN          Slovenia                        1960  2022
# SWE          Sweden                          2022  2022
# SWZ          Eswatini                        2022  2022
# SYC          Seychelles                      2022  2022
# SYR          Syrian Arab Republic            2022  2022
# TCD          Chad                            2022  2022
# TGO          Togo                            2022  2022
# THA          Thailand                        2022  2022
# TJK          Tajikistan                      1960  2022
# TKM          Turkmenistan                    1960  2022
# TLS          Timor-Leste                     2022  2022
# TON          Tonga                           1960  2022
# TTO          Trinidad and Tobago             2022  2022
# TUN          Tunisia                         2022  2022
# TUR          Turkiye                         2022  2022
# TUV          Tuvalu                          1960  2022
# TZA          Tanzania                        2022  2022
# UGA          Uganda                          2022  2022
# UKR          Ukraine                         1960  2022
# URY          Uruguay                         2022  2022
# USA          United States                   2022  2022
# UZB          Uzbekistan                      1960  2022
# VCT          St. Vincent and the Grenadines  1960  2022
# VEN          Venezuela, RB                   2022  2022
# VNM          Vietnam                         2022  2022
# VUT          Vanuatu                         2022  2022
# WSM          Samoa                           1960  2022
# YEM          Yemen, Rep.                     2022  2022
# ZAF          South Africa                    2022  2022
# ZMB          Zambia                          2022  2022
# ZWE          Zimbabwe                        2022  2022

# %%
left_only['country_name_wb'].unique()
# Out:
# array(['Afghanistan', 'Angola', 'Albania', 'Andorra',
#        'United Arab Emirates', 'Argentina', 'Armenia',
#        'Antigua and Barbuda', 'Australia', 'Austria', 'Azerbaijan',
#        'Burundi', 'Belgium', 'Benin', 'Burkina Faso', 'Bangladesh',
#        'Bulgaria', 'Bahrain', 'Bahamas, The', 'Bosnia and Herzegovina',
#        'Belarus', 'Belize', 'Bolivia', 'Brazil', 'Barbados',
#        'Brunei Darussalam', 'Bhutan', 'Botswana',
#        'Central African Republic', 'Canada', 'Switzerland', 'Chile',
#        'China', "Cote d'Ivoire", 'Cameroon', 'Congo, Dem. Rep.',
#        'Congo, Rep.', 'Colombia', 'Comoros', 'Cabo Verde', 'Costa Rica',
#        'Cuba', 'Cyprus', 'Czechia', 'Germany', 'Djibouti', 'Dominica',
#        'Denmark', 'Dominican Republic', 'Algeria', 'Ecuador',
#        'Egypt, Arab Rep.', 'Eritrea', 'Spain', 'Estonia', 'Ethiopia',
#        'Finland', 'Fiji', 'France', 'Micronesia, Fed. Sts.', 'Gabon',
#        'United Kingdom', 'Georgia', 'Ghana', 'Guinea', 'Gambia, The',
#        'Guinea-Bissau', 'Equatorial Guinea', 'Greece', 'Grenada',
#        'Guatemala', 'Guyana', 'Honduras', 'Croatia', 'Haiti', 'Hungary',
#        'Indonesia', 'India', 'Ireland', 'Iran, Islamic Rep.', 'Iraq',
#        'Iceland', 'Israel', 'Italy', 'Jamaica', 'Jordan', 'Japan',
#        'Kazakhstan', 'Kenya', 'Kyrgyz Republic', 'Cambodia', 'Kiribati',
#        'St. Kitts and Nevis', 'Korea, Rep.', 'Kuwait', 'Lao PDR',
#        'Lebanon', 'Liberia', 'Libya', 'St. Lucia', 'Liechtenstein',
#        'Sri Lanka', 'Lesotho', 'Lithuania', 'Luxembourg', 'Latvia',
#        'Morocco', 'Monaco', 'Moldova', 'Madagascar', 'Maldives', 'Mexico',
#        'Marshall Islands', 'North Macedonia', 'Mali', 'Malta', 'Myanmar',
#        'Montenegro', 'Mongolia', 'Mozambique', 'Mauritania', 'Mauritius',
#        'Malawi', 'Malaysia', 'Namibia', 'Niger', 'Nigeria', 'Nicaragua',
#        'Netherlands', 'Norway', 'Nepal', 'Nauru', 'New Zealand', 'Oman',
#        'Pakistan', 'Panama', 'Peru', 'Philippines', 'Palau',
#        'Papua New Guinea', 'Poland', "Korea, Dem. People's Rep.",
#        'Portugal', 'Paraguay', 'Qatar', 'Romania', 'Russian Federation',
#        'Rwanda', 'Saudi Arabia', 'Sudan', 'Senegal', 'Singapore',
#        'Solomon Islands', 'Sierra Leone', 'El Salvador', 'San Marino',
#        'Somalia', 'Serbia', 'South Sudan', 'Sao Tome and Principe',
#        'Suriname', 'Slovak Republic', 'Slovenia', 'Sweden', 'Eswatini',
#        'Seychelles', 'Syrian Arab Republic', 'Chad', 'Togo', 'Thailand',
#        'Tajikistan', 'Turkmenistan', 'Timor-Leste', 'Tonga',
#        'Trinidad and Tobago', 'Tunisia', 'Turkiye', 'Tuvalu', 'Tanzania',
#        'Uganda', 'Ukraine', 'Uruguay', 'United States', 'Uzbekistan',
#        'St. Vincent and the Grenadines', 'Venezuela, RB', 'Vietnam',
#        'Vanuatu', 'Samoa', 'Yemen, Rep.', 'South Africa', 'Zambia',
#        'Zimbabwe'], dtype=object)

# %%
right_only = merged_df.query("_merge == 'right_only'")
right_only_years = right_only.groupby(['country_code', 'country_name_vdem'])['year'].agg(['min', 'max'])
right_only_years
# Out:
#                                           min   max
# country_code country_name_vdem
# DDR          German Democratic Republic  1960  1990
# HKG          Hong Kong                   1960  2021
# PSE          Palestine/West Bank         1967  2021
# PSG          Palestine/Gaza              1960  2021
# SML          Somaliland                  1991  2021
# TWN          Taiwan                      1960  2021
# VDR          Republic of Vietnam         1960  1975
# XKX          Kosovo                      1999  2021
# YMD          South Yemen                 1960  1990
# ZZB          Zanzibar                    1960  2021

# %% [markdown]
# ## K.
#
# - There are some countries that have different spellings between data sets. For example, South Yemen in Vdem and Republic of Yemen could refer to the same country, although there are political reasons as to why this may not be true.
# - Many of the countries present in the vdem data set that are not present in the wb data set are countries that no longer exist, such as East Germany (German Democratic Republic) or the Republic of Vietnam. In addition, the vdem dataset recognizes Hong Kong, Taiwan,  Somolialand while the wb data set does not.
# - It appears that the wb_clean data set has more up-to-date statistics than the vdem_clean data set (going up to 2022 as opposed to 2021).

# %%
timeseries = pd.merge(wb_clean, vdem_clean, on=['country_code', 'year'], how='inner')
timeseries
# Out:
#      country_code country_name_wb  year  \
# 0             AFG     Afghanistan  1960
# 1             AFG     Afghanistan  1961
# 2             AFG     Afghanistan  1962
# 3             AFG     Afghanistan  1963
# 4             AFG     Afghanistan  1964
# ...           ...             ...   ...
# 9971          ZWE        Zimbabwe  2017
# 9972          ZWE        Zimbabwe  2018
# 9973          ZWE        Zimbabwe  2019
# 9974          ZWE        Zimbabwe  2020
# 9975          ZWE        Zimbabwe  2021
#
#       access_to_clean_fuels_and_technologies_for_cooking  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9971                                               29.8
# 9972                                               30.0
# 9973                                               30.2
# 9974                                               30.3
# 9975                                               30.3
#
#       access_to_electricity  agricultural_land  agriculture  \
# 0                       NaN                NaN          NaN
# 1                       NaN          57.878356          NaN
# 2                       NaN          57.955016          NaN
# 3                       NaN          58.031676          NaN
# 4                       NaN          58.116002          NaN
# ...                     ...                ...          ...
# 9971              43.979065          41.876696     8.340969
# 9972              45.400288          41.876696     7.319375
# 9973              46.682095          41.876696     9.819262
# 9974              52.747667          41.876696     8.772859
# 9975              48.979927          41.876696     8.849899
#
#       annual_freshwater_withdrawals  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 9971                      27.234910
# 9972                      30.761677
# 9973                      30.761677
# 9974                      30.761677
# 9975                            NaN
#
#       annualized_average_growth_rate_in_per_capita_real_surve  cause_of_death  \
# 0                                                   NaN                   NaN
# 1                                                   NaN                   NaN
# 2                                                   NaN                   NaN
# 3                                                   NaN                   NaN
# 4                                                   NaN                   NaN
# ...                                                 ...                   ...
# 9971                                               -3.5                   NaN
# 9972                                                NaN                   NaN
# 9973                                                NaN             47.647301
# 9974                                                NaN                   NaN
# 9975                                                NaN                   NaN
#
#       ...  scientific_and_technical_journal_articles  \
# 0     ...                                        NaN
# 1     ...                                        NaN
# 2     ...                                        NaN
# 3     ...                                        NaN
# 4     ...                                        NaN
# ...   ...                                        ...
# 9971  ...                                     334.71
# 9972  ...                                     406.23
# 9973  ...                                     431.62
# 9974  ...                                     480.16
# 9975  ...                                        NaN
#
#       strength_of_legal_rights_index  terrestrial_and_marine_protected_areas  \
# 0                                NaN                                     NaN
# 1                                NaN                                     NaN
# 2                                NaN                                     NaN
# 3                                NaN                                     NaN
# 4                                NaN                                     NaN
# ...                              ...                                     ...
# 9971                             5.0                               27.214585
# 9972                             5.0                               27.214585
# 9973                             6.0                               27.214747
# 9974                             NaN                               27.214747
# 9975                             NaN                               27.214747
#
#       tree_cover_loss  unemployment  unmet_need_for_contraception  \
# 0                 NaN           NaN                           NaN
# 1                 NaN           NaN                           NaN
# 2                 NaN           NaN                           NaN
# 3                 NaN           NaN                           NaN
# 4                 NaN           NaN                           NaN
# ...               ...           ...                           ...
# 9971              NaN         6.279                           NaN
# 9972              NaN         6.784                           NaN
# 9973              NaN         7.370                           NaN
# 9974              NaN         7.898                           NaN
# 9975              NaN         8.067                           NaN
#
#       voice_and_accountability  water_quality  country_name_vdem  democracy
# 0                          NaN            NaN        Afghanistan      0.080
# 1                          NaN            NaN        Afghanistan      0.083
# 2                          NaN            NaN        Afghanistan      0.082
# 3                          NaN            NaN        Afghanistan      0.085
# 4                          NaN            NaN        Afghanistan      0.137
# ...                        ...            ...                ...        ...
# 9971                 -1.195905           76.5           Zimbabwe      0.295
# 9972                 -1.136798            NaN           Zimbabwe      0.305
# 9973                 -1.163669            NaN           Zimbabwe      0.293
# 9974                 -1.113408           83.3           Zimbabwe      0.293
# 9975                 -1.135830            NaN           Zimbabwe      0.291
#
# [9976 rows x 76 columns]

# %% [markdown]
# ## Part 3: 1NF, 2NF, 3NF

# %%
country = country_clean
country.head(10)
# Out:
#    country_code       country_name_wb              country_longname  \
# 0           AFG           Afghanistan  Islamic State of Afghanistan
# 1           AGO                Angola   People's Republic of Angola
# 2           ALB               Albania           Republic of Albania
# 3           AND               Andorra       Principality of Andorra
# 5           ARE  United Arab Emirates          United Arab Emirates
# 6           ARG             Argentina            Argentine Republic
# 7           ARM               Armenia           Republic of Armenia
# 8           ATG   Antigua and Barbuda           Antigua and Barbuda
# 9           AUS             Australia     Commonwealth of Australia
# 10          AUT               Austria           Republic of Austria
#
#             currency_unit                      region         income_group
# 0          Afghan afghani                  South Asia           Low income
# 1          Angolan kwanza          Sub-Saharan Africa  Lower middle income
# 2            Albanian lek       Europe & Central Asia  Upper middle income
# 3                    Euro       Europe & Central Asia          High income
# 5           U.A.E. dirham  Middle East & North Africa          High income
# 6          Argentine peso   Latin America & Caribbean  Upper middle income
# 7           Armenian dram       Europe & Central Asia  Upper middle income
# 8   East Caribbean dollar   Latin America & Caribbean          High income
# 9       Australian dollar         East Asia & Pacific          High income
# 10                   Euro       Europe & Central Asia          High income

# %%
world = whole_world_data_clean
world.tail(10)
# Out:
# feature  year  world_access_to_clean_fuels_and_technologies_for_cooking  \
# 11897    2013                                          61.095607
# 11898    2014                                          62.372600
# 11899    2015                                          63.662869
# 11900    2016                                          65.005668
# 11901    2017                                          66.321819
# 11902    2018                                          67.696517
# 11903    2019                                          68.921601
# 11904    2020                                          70.184805
# 11905    2021                                          71.331487
# 11906    2022                                                NaN
#
# feature  world_access_to_electricity  world_agricultural_land  \
# 11897                      85.817366                36.790232
# 11898                      86.306969                36.789051
# 11899                      87.025241                36.620496
# 11900                      88.192385                36.587014
# 11901                      89.019548                36.834001
# 11902                      89.893733                36.738458
# 11903                      90.194716                36.762648
# 11904                      90.483629                36.730920
# 11905                      91.413941                36.841665
# 11906                            NaN                      NaN
#
# feature  world_agriculture  world_annual_freshwater_withdrawals  \
# 11897             4.153018                                  NaN
# 11898             4.138056                             8.997850
# 11899             4.224637                             9.001010
# 11900             4.179066                             9.097086
# 11901             4.146421                             9.160457
# 11902             3.951747                             9.137864
# 11903             4.013242                             9.167900
# 11904             4.352489                             9.109511
# 11905             4.304093                                  NaN
# 11906             4.329327                                  NaN
#
# feature  world_annualized_average_growth_rate_in_per_capita_real_surve  \
# 11897                                                  NaN
# 11898                                                  NaN
# 11899                                                  NaN
# 11900                                                  NaN
# 11901                                                  NaN
# 11902                                                  NaN
# 11903                                                  NaN
# 11904                                                  NaN
# 11905                                                  NaN
# 11906                                                  NaN
#
# feature  world_cause_of_death  world_children_in_employment  \
# 11897                     NaN                           NaN
# 11898                     NaN                           NaN
# 11899               20.476064                           NaN
# 11900                     NaN                           NaN
# 11901                     NaN                           NaN
# 11902                     NaN                           NaN
# 11903               18.408850                           NaN
# 11904                     NaN                           NaN
# 11905                     NaN                           NaN
# 11906                     NaN                           NaN
#
# feature  world_co2_emissions  ...  world_research_and_development_expenditure  \
# 11897               4.719386  ...                                    1.987380
# 11898               4.681813  ...                                    2.067215
# 11899               4.600797  ...                                    2.094953
# 11900               4.557520  ...                                    2.137829
# 11901               4.577306  ...                                    2.133375
# 11902               4.641294  ...                                    2.196050
# 11903               4.582036  ...                                    2.331934
# 11904               4.291853  ...                                    2.627081
# 11905                    NaN  ...                                         NaN
# 11906                    NaN  ...                                         NaN
#
# feature  world_rule_of_law  world_scientific_and_technical_journal_articles  \
# 11897                  NaN                                     2.149756e+06
# 11898                  NaN                                     2.223226e+06
# 11899                  NaN                                     2.275681e+06
# 11900                  NaN                                     2.356515e+06
# 11901                  NaN                                     2.430534e+06
# 11902                  NaN                                     2.565871e+06
# 11903                  NaN                                     2.734962e+06
# 11904                  NaN                                     2.933011e+06
# 11905                  NaN                                              NaN
# 11906                  NaN                                              NaN
#
# feature  world_strength_of_legal_rights_index  \
# 11897                                4.677249
# 11898                                4.804233
# 11899                                4.942105
# 11900                                5.036842
# 11901                                5.347368
# 11902                                5.507853
# 11903                                5.685864
# 11904                                     NaN
# 11905                                     NaN
# 11906                                     NaN
#
# feature  world_terrestrial_and_marine_protected_areas  world_tree_cover_loss  \
# 11897                                             NaN                    NaN
# 11898                                             NaN                    NaN
# 11899                                             NaN                    NaN
# 11900                                       13.345680                    NaN
# 11901                                       14.337488                    NaN
# 11902                                       14.337515                    NaN
# 11903                                       14.599801                    NaN
# 11904                                       14.787111                    NaN
# 11905                                       14.552260                    NaN
# 11906                                             NaN                    NaN
#
# feature  world_unemployment  world_unmet_need_for_contraception  \
# 11897              6.116253                                 NaN
# 11898              5.981353                                 NaN
# 11899              6.010888                                 NaN
# 11900              6.003205                                 NaN
# 11901              5.873644                                 NaN
# 11902              5.699076                                 NaN
# 11903              5.543161                                 NaN
# 11904              6.898273                                 NaN
# 11905              6.201871                                 NaN
# 11906              5.772710                                 NaN
#
# feature  world_voice_and_accountability  world_water_quality
# 11897                               NaN                  NaN
# 11898                               NaN                  NaN
# 11899                               NaN                  NaN
# 11900                               NaN                  NaN
# 11901                               NaN                  NaN
# 11902                               NaN                  NaN
# 11903                               NaN                  NaN
# 11904                               NaN                  NaN
# 11905                               NaN                  NaN
# 11906                               NaN                  NaN
#
# [10 rows x 72 columns]

# %%
world.tail(20)
# Out:
# feature  year  world_access_to_clean_fuels_and_technologies_for_cooking  \
# 11887    2003                                          51.040051
# 11888    2004                                          51.769412
# 11889    2005                                          52.495195
# 11890    2006                                          53.344280
# 11891    2007                                          54.374873
# 11892    2008                                          55.310321
# 11893    2009                                          56.413537
# 11894    2010                                          57.446700
# 11895    2011                                          58.688718
# 11896    2012                                          59.843821
# 11897    2013                                          61.095607
# 11898    2014                                          62.372600
# 11899    2015                                          63.662869
# 11900    2016                                          65.005668
# 11901    2017                                          66.321819
# 11902    2018                                          67.696517
# 11903    2019                                          68.921601
# 11904    2020                                          70.184805
# 11905    2021                                          71.331487
# 11906    2022                                                NaN
#
# feature  world_access_to_electricity  world_agricultural_land  \
# 11887                      80.093097                37.331860
# 11888                      80.063555                36.970535
# 11889                      80.835949                37.026447
# 11890                      81.468864                37.037442
# 11891                      82.095816                36.972918
# 11892                      82.788799                36.855935
# 11893                      82.983962                36.810782
# 11894                      83.566033                36.805434
# 11895                      84.624339                36.949919
# 11896                      85.058874                36.867753
# 11897                      85.817366                36.790232
# 11898                      86.306969                36.789051
# 11899                      87.025241                36.620496
# 11900                      88.192385                36.587014
# 11901                      89.019548                36.834001
# 11902                      89.893733                36.738458
# 11903                      90.194716                36.762648
# 11904                      90.483629                36.730920
# 11905                      91.413941                36.841665
# 11906                            NaN                      NaN
#
# feature  world_agriculture  world_annual_freshwater_withdrawals  \
# 11887             3.317709                                  NaN
# 11888             3.358506                                  NaN
# 11889             3.232600                                  NaN
# 11890             3.213357                                  NaN
# 11891             3.384562                                  NaN
# 11892             3.550710                                  NaN
# 11893             3.682286                                  NaN
# 11894             3.877757                                  NaN
# 11895             3.984953                                  NaN
# 11896             4.019590                                  NaN
# 11897             4.153018                                  NaN
# 11898             4.138056                             8.997850
# 11899             4.224637                             9.001010
# 11900             4.179066                             9.097086
# 11901             4.146421                             9.160457
# 11902             3.951747                             9.137864
# 11903             4.013242                             9.167900
# 11904             4.352489                             9.109511
# 11905             4.304093                                  NaN
# 11906             4.329327                                  NaN
#
# feature  world_annualized_average_growth_rate_in_per_capita_real_surve  \
# 11887                                                  NaN
# 11888                                                  NaN
# 11889                                                  NaN
# 11890                                                  NaN
# 11891                                                  NaN
# 11892                                                  NaN
# 11893                                                  NaN
# 11894                                                  NaN
# 11895                                                  NaN
# 11896                                                  NaN
# 11897                                                  NaN
# 11898                                                  NaN
# 11899                                                  NaN
# 11900                                                  NaN
# 11901                                                  NaN
# 11902                                                  NaN
# 11903                                                  NaN
# 11904                                                  NaN
# 11905                                                  NaN
# 11906                                                  NaN
#
# feature  world_cause_of_death  world_children_in_employment  \
# 11887                     NaN                           NaN
# 11888                     NaN                           NaN
# 11889                     NaN                           NaN
# 11890                     NaN                           NaN
# 11891                     NaN                           NaN
# 11892                     NaN                           NaN
# 11893                     NaN                           NaN
# 11894               23.513641                           NaN
# 11895                     NaN                           NaN
# 11896                     NaN                           NaN
# 11897                     NaN                           NaN
# 11898                     NaN                           NaN
# 11899               20.476064                           NaN
# 11900                     NaN                           NaN
# 11901                     NaN                           NaN
# 11902                     NaN                           NaN
# 11903               18.408850                           NaN
# 11904                     NaN                           NaN
# 11905                     NaN                           NaN
# 11906                     NaN                           NaN
#
# feature  world_co2_emissions  ...  world_research_and_development_expenditure  \
# 11887               4.090082  ...                                    2.025421
# 11888               4.223794  ...                                    1.976993
# 11889               4.329790  ...                                    1.959438
# 11890               4.417135  ...                                    1.969281
# 11891               4.528066  ...                                    1.936991
# 11892               4.503617  ...                                    1.990412
# 11893               4.391332  ...                                    2.028198
# 11894               4.604834  ...                                    2.013410
# 11895               4.689502  ...                                    1.998631
# 11896               4.685310  ...                                    2.024837
# 11897               4.719386  ...                                    1.987380
# 11898               4.681813  ...                                    2.067215
# 11899               4.600797  ...                                    2.094953
# 11900               4.557520  ...                                    2.137829
# 11901               4.577306  ...                                    2.133375
# 11902               4.641294  ...                                    2.196050
# 11903               4.582036  ...                                    2.331934
# 11904               4.291853  ...                                    2.627081
# 11905                    NaN  ...                                         NaN
# 11906                    NaN  ...                                         NaN
#
# feature  world_rule_of_law  world_scientific_and_technical_journal_articles  \
# 11887                  NaN                                     1.214598e+06
# 11888                  NaN                                     1.327931e+06
# 11889                  NaN                                     1.489848e+06
# 11890                  NaN                                     1.580501e+06
# 11891                  NaN                                     1.648986e+06
# 11892                  NaN                                     1.742799e+06
# 11893                  NaN                                     1.844539e+06
# 11894                  NaN                                     1.929771e+06
# 11895                  NaN                                     2.028063e+06
# 11896                  NaN                                     2.083570e+06
# 11897                  NaN                                     2.149756e+06
# 11898                  NaN                                     2.223226e+06
# 11899                  NaN                                     2.275681e+06
# 11900                  NaN                                     2.356515e+06
# 11901                  NaN                                     2.430534e+06
# 11902                  NaN                                     2.565871e+06
# 11903                  NaN                                     2.734962e+06
# 11904                  NaN                                     2.933011e+06
# 11905                  NaN                                              NaN
# 11906                  NaN                                              NaN
#
# feature  world_strength_of_legal_rights_index  \
# 11887                                     NaN
# 11888                                     NaN
# 11889                                     NaN
# 11890                                     NaN
# 11891                                     NaN
# 11892                                     NaN
# 11893                                     NaN
# 11894                                     NaN
# 11895                                     NaN
# 11896                                     NaN
# 11897                                4.677249
# 11898                                4.804233
# 11899                                4.942105
# 11900                                5.036842
# 11901                                5.347368
# 11902                                5.507853
# 11903                                5.685864
# 11904                                     NaN
# 11905                                     NaN
# 11906                                     NaN
#
# feature  world_terrestrial_and_marine_protected_areas  world_tree_cover_loss  \
# 11887                                             NaN                    NaN
# 11888                                             NaN                    NaN
# 11889                                             NaN                    NaN
# 11890                                             NaN                    NaN
# 11891                                             NaN                    NaN
# 11892                                             NaN                    NaN
# 11893                                             NaN                    NaN
# 11894                                             NaN                    NaN
# 11895                                             NaN                    NaN
# 11896                                             NaN                    NaN
# 11897                                             NaN                    NaN
# 11898                                             NaN                    NaN
# 11899                                             NaN                    NaN
# 11900                                       13.345680                    NaN
# 11901                                       14.337488                    NaN
# 11902                                       14.337515                    NaN
# 11903                                       14.599801                    NaN
# 11904                                       14.787111                    NaN
# 11905                                       14.552260                    NaN
# 11906                                             NaN                    NaN
#
# feature  world_unemployment  world_unmet_need_for_contraception  \
# 11887              6.541302                                 NaN
# 11888              6.415079                                 NaN
# 11889              6.337354                                 NaN
# 11890              6.063916                                 NaN
# 11891              5.850847                                 NaN
# 11892              5.869603                                 NaN
# 11893              6.460828                                 NaN
# 11894              6.345892                                 NaN
# 11895              6.191783                                 NaN
# 11896              6.138787                                 NaN
# 11897              6.116253                                 NaN
# 11898              5.981353                                 NaN
# 11899              6.010888                                 NaN
# 11900              6.003205                                 NaN
# 11901              5.873644                                 NaN
# 11902              5.699076                                 NaN
# 11903              5.543161                                 NaN
# 11904              6.898273                                 NaN
# 11905              6.201871                                 NaN
# 11906              5.772710                                 NaN
#
# feature  world_voice_and_accountability  world_water_quality
# 11887                               NaN                  NaN
# 11888                               NaN                  NaN
# 11889                               NaN                  NaN
# 11890                               NaN                  NaN
# 11891                               NaN                  NaN
# 11892                               NaN                  NaN
# 11893                               NaN                  NaN
# 11894                               NaN                  NaN
# 11895                               NaN                  NaN
# 11896                               NaN                  NaN
# 11897                               NaN                  NaN
# 11898                               NaN                  NaN
# 11899                               NaN                  NaN
# 11900                               NaN                  NaN
# 11901                               NaN                  NaN
# 11902                               NaN                  NaN
# 11903                               NaN                  NaN
# 11904                               NaN                  NaN
# 11905                               NaN                  NaN
# 11906                               NaN                  NaN
#
# [20 rows x 72 columns]

# %%
timeseries.head(10)
# Out:
#   country_code country_name_wb  year  \
# 0          AFG     Afghanistan  1960
# 1          AFG     Afghanistan  1961
# 2          AFG     Afghanistan  1962
# 3          AFG     Afghanistan  1963
# 4          AFG     Afghanistan  1964
# 5          AFG     Afghanistan  1965
# 6          AFG     Afghanistan  1966
# 7          AFG     Afghanistan  1967
# 8          AFG     Afghanistan  1968
# 9          AFG     Afghanistan  1969
#
#    access_to_clean_fuels_and_technologies_for_cooking  access_to_electricity  \
# 0                                                NaN                     NaN
# 1                                                NaN                     NaN
# 2                                                NaN                     NaN
# 3                                                NaN                     NaN
# 4                                                NaN                     NaN
# 5                                                NaN                     NaN
# 6                                                NaN                     NaN
# 7                                                NaN                     NaN
# 8                                                NaN                     NaN
# 9                                                NaN                     NaN
#
#    agricultural_land  agriculture  annual_freshwater_withdrawals  \
# 0                NaN          NaN                            NaN
# 1          57.878356          NaN                            NaN
# 2          57.955016          NaN                            NaN
# 3          58.031676          NaN                            NaN
# 4          58.116002          NaN                            NaN
# 5          58.123668          NaN                            NaN
# 6          58.192662          NaN                            NaN
# 7          58.229459          NaN                            NaN
# 8          58.230992          NaN                            NaN
# 9          58.255523          NaN                            NaN
#
#    annualized_average_growth_rate_in_per_capita_real_surve  cause_of_death  \
# 0                                                NaN                   NaN
# 1                                                NaN                   NaN
# 2                                                NaN                   NaN
# 3                                                NaN                   NaN
# 4                                                NaN                   NaN
# 5                                                NaN                   NaN
# 6                                                NaN                   NaN
# 7                                                NaN                   NaN
# 8                                                NaN                   NaN
# 9                                                NaN                   NaN
#
#    ...  scientific_and_technical_journal_articles  \
# 0  ...                                        NaN
# 1  ...                                        NaN
# 2  ...                                        NaN
# 3  ...                                        NaN
# 4  ...                                        NaN
# 5  ...                                        NaN
# 6  ...                                        NaN
# 7  ...                                        NaN
# 8  ...                                        NaN
# 9  ...                                        NaN
#
#    strength_of_legal_rights_index  terrestrial_and_marine_protected_areas  \
# 0                             NaN                                     NaN
# 1                             NaN                                     NaN
# 2                             NaN                                     NaN
# 3                             NaN                                     NaN
# 4                             NaN                                     NaN
# 5                             NaN                                     NaN
# 6                             NaN                                     NaN
# 7                             NaN                                     NaN
# 8                             NaN                                     NaN
# 9                             NaN                                     NaN
#
#    tree_cover_loss  unemployment  unmet_need_for_contraception  \
# 0              NaN           NaN                           NaN
# 1              NaN           NaN                           NaN
# 2              NaN           NaN                           NaN
# 3              NaN           NaN                           NaN
# 4              NaN           NaN                           NaN
# 5              NaN           NaN                           NaN
# 6              NaN           NaN                           NaN
# 7              NaN           NaN                           NaN
# 8              NaN           NaN                           NaN
# 9              NaN           NaN                           NaN
#
#    voice_and_accountability  water_quality  country_name_vdem  democracy
# 0                       NaN            NaN        Afghanistan      0.080
# 1                       NaN            NaN        Afghanistan      0.083
# 2                       NaN            NaN        Afghanistan      0.082
# 3                       NaN            NaN        Afghanistan      0.085
# 4                       NaN            NaN        Afghanistan      0.137
# 5                       NaN            NaN        Afghanistan      0.150
# 6                       NaN            NaN        Afghanistan      0.161
# 7                       NaN            NaN        Afghanistan      0.163
# 8                       NaN            NaN        Afghanistan      0.163
# 9                       NaN            NaN        Afghanistan      0.162
#
# [10 rows x 76 columns]

# %% [markdown]
# **Country Dataframe**
# This data frame appears to be in the 1NF because each column has atomic values, there are no repeating groups, and each column has a unique name. Since 'country_code' is a primary key the country data frame also appears to be in 2NF since all other columns (such as 'region') are functionally dependent on the 'country_code'. Finally, this data frame appears to be in 3NF because there does not appear to be any transitive dependency.
#
# **Timeseries Dataframe**
# This data frame appears to be in the 1NF because each column has atomic values, there are no repeating groups, and each column has a unique name. There are two primary keys in this data frame, that being 'country_code' and "year". For similar reasons above, this data frame appears to be in 2N and 3N. However, in order for all three dataframes to be in the 3N, then we do not need the country_name_wb nor the country_name_vdem column as this is repeated in the country dataframe.
#
#
# **World Dataframe**
# The world data frame is in 1NF because each column has atomic values, there are no repeating groups, and each column has a unique name. The primary key is the year and the other columns are functionally dependent on the 'year'. Hence, it is in 2NF. Finally, there does not appear to be any transitive dependency.

# %%
# Dropping the 'country_names_wb' column from Timeseries dataframe. 
timeseries = timeseries.drop(['country_name_wb', 'country_name_vdem'], axis=1)

# %%
timeseries.head(2)
# Out:
#   country_code  year  access_to_clean_fuels_and_technologies_for_cooking  \
# 0          AFG  1960                                                NaN
# 1          AFG  1961                                                NaN
#
#    access_to_electricity  agricultural_land  agriculture  \
# 0                    NaN                NaN          NaN
# 1                    NaN          57.878356          NaN
#
#    annual_freshwater_withdrawals  \
# 0                            NaN
# 1                            NaN
#
#    annualized_average_growth_rate_in_per_capita_real_surve  cause_of_death  \
# 0                                                NaN                   NaN
# 1                                                NaN                   NaN
#
#    children_in_employment  ...  rule_of_law  \
# 0                     NaN  ...          NaN
# 1                     NaN  ...          NaN
#
#    scientific_and_technical_journal_articles  strength_of_legal_rights_index  \
# 0                                        NaN                             NaN
# 1                                        NaN                             NaN
#
#    terrestrial_and_marine_protected_areas  tree_cover_loss  unemployment  \
# 0                                     NaN              NaN           NaN
# 1                                     NaN              NaN           NaN
#
#    unmet_need_for_contraception  voice_and_accountability  water_quality  \
# 0                           NaN                       NaN            NaN
# 1                           NaN                       NaN            NaN
#
#    democracy
# 0      0.080
# 1      0.083
#
# [2 rows x 74 columns]

# %% [markdown]
# # Task Four

# %%
lab3network = psycopg2.connect(
    host = 'postgres',
    user = 'postgres',
    password = POSTGRES_PASSWORD,
    port = 5432
)
lab3network.autocommit = True

# %%
cursor = lab3network.cursor()

# %%
try: 
    cursor.execute('CREATE DATABASE cardib')
except:
    cursor.execute ('DROP DATABASE cardib')
    cursor.execute ( 'CREATE DATABASE cardib')

# %%
engine = create_engine ('postgresql+psycopg2://{user}:{password}@{host}:{port}/{db}'.format(
user = 'postgres',
password = POSTGRES_PASSWORD,
host = 'postgres',
port = 5432,
db = 'cardib'
))

# %%
print(country.shape[0])
country.to_sql('country', con=engine, index=False, chunksize=1000,
               if_exists = 'replace')
# Out:
# 193
# 193

# %%
print(timeseries.shape[0])
timeseries.to_sql('timeseries', con=engine, index=False, chunksize=100,
               if_exists = 'replace')
# Out:
# 9976
# 9976

# %%
print(world.shape[0])
world.to_sql('world', con=engine, index=False, chunksize=1000,
               if_exists = 'replace')
# Out:
# 63
# 63

# %%
timeseries.head(10)
# Out:
#   country_code  year  access_to_clean_fuels_and_technologies_for_cooking  \
# 0          AFG  1960                                                NaN
# 1          AFG  1961                                                NaN
# 2          AFG  1962                                                NaN
# 3          AFG  1963                                                NaN
# 4          AFG  1964                                                NaN
# 5          AFG  1965                                                NaN
# 6          AFG  1966                                                NaN
# 7          AFG  1967                                                NaN
# 8          AFG  1968                                                NaN
# 9          AFG  1969                                                NaN
#
#    access_to_electricity  agricultural_land  agriculture  \
# 0                    NaN                NaN          NaN
# 1                    NaN          57.878356          NaN
# 2                    NaN          57.955016          NaN
# 3                    NaN          58.031676          NaN
# 4                    NaN          58.116002          NaN
# 5                    NaN          58.123668          NaN
# 6                    NaN          58.192662          NaN
# 7                    NaN          58.229459          NaN
# 8                    NaN          58.230992          NaN
# 9                    NaN          58.255523          NaN
#
#    annual_freshwater_withdrawals  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# 5                            NaN
# 6                            NaN
# 7                            NaN
# 8                            NaN
# 9                            NaN
#
#    annualized_average_growth_rate_in_per_capita_real_surve  cause_of_death  \
# 0                                                NaN                   NaN
# 1                                                NaN                   NaN
# 2                                                NaN                   NaN
# 3                                                NaN                   NaN
# 4                                                NaN                   NaN
# 5                                                NaN                   NaN
# 6                                                NaN                   NaN
# 7                                                NaN                   NaN
# 8                                                NaN                   NaN
# 9                                                NaN                   NaN
#
#    children_in_employment  ...  rule_of_law  \
# 0                     NaN  ...          NaN
# 1                     NaN  ...          NaN
# 2                     NaN  ...          NaN
# 3                     NaN  ...          NaN
# 4                     NaN  ...          NaN
# 5                     NaN  ...          NaN
# 6                     NaN  ...          NaN
# 7                     NaN  ...          NaN
# 8                     NaN  ...          NaN
# 9                     NaN  ...          NaN
#
#    scientific_and_technical_journal_articles  strength_of_legal_rights_index  \
# 0                                        NaN                             NaN
# 1                                        NaN                             NaN
# 2                                        NaN                             NaN
# 3                                        NaN                             NaN
# 4                                        NaN                             NaN
# 5                                        NaN                             NaN
# 6                                        NaN                             NaN
# 7                                        NaN                             NaN
# 8                                        NaN                             NaN
# 9                                        NaN                             NaN
#
#    terrestrial_and_marine_protected_areas  tree_cover_loss  unemployment  \
# 0                                     NaN              NaN           NaN
# 1                                     NaN              NaN           NaN
# 2                                     NaN              NaN           NaN
# 3                                     NaN              NaN           NaN
# 4                                     NaN              NaN           NaN
# 5                                     NaN              NaN           NaN
# 6                                     NaN              NaN           NaN
# 7                                     NaN              NaN           NaN
# 8                                     NaN              NaN           NaN
# 9                                     NaN              NaN           NaN
#
#    unmet_need_for_contraception  voice_and_accountability  water_quality  \
# 0                           NaN                       NaN            NaN
# 1                           NaN                       NaN            NaN
# 2                           NaN                       NaN            NaN
# 3                           NaN                       NaN            NaN
# 4                           NaN                       NaN            NaN
# 5                           NaN                       NaN            NaN
# 6                           NaN                       NaN            NaN
# 7                           NaN                       NaN            NaN
# 8                           NaN                       NaN            NaN
# 9                           NaN                       NaN            NaN
#
#    democracy
# 0      0.080
# 1      0.083
# 2      0.082
# 3      0.085
# 4      0.137
# 5      0.150
# 6      0.161
# 7      0.163
# 8      0.163
# 9      0.162
#
# [10 rows x 74 columns]

# %% [markdown]
# # Task Five

# %% [markdown]
# see cardibdb.dbml

# %% [markdown]
# https://dbdocs.io/elizabethmillerwc/Cardibi

# %% [markdown]
# ## 6.

# %%
#a. what countries had the highest quality democracies in the year 2021?
myquery = '''
SELECT c.country_name_wb AS country, ts.democracy
FROM timeseries ts
INNER JOIN country c
    ON ts.country_code = c.country_code
WHERE year = 2021
ORDER BY ts.democracy DESC nulls last
'''
 
pd.read_sql_query(myquery, con=engine)
# Out:
#                        country  democracy
# 0                      Denmark      0.915
# 1                       Sweden      0.903
# 2                       Norway      0.901
# 3                   Costa Rica      0.898
# 4                  Switzerland      0.898
# ..                         ...        ...
# 167                      Qatar      0.090
# 168  Korea, Dem. People's Rep.      0.086
# 169                      China      0.077
# 170                    Eritrea      0.072
# 171               Saudi Arabia      0.016
#
# [172 rows x 2 columns]

# %%
#b. How does the life expectancy at birth for Chile compare to the glbal average life expectancy at birth over the 1960-2021?
myquery = '''
SELECT ts.year, c.country_code, ts.life_expectancy_at_birth, w.world_life_expectancy_at_birth
FROM timeseries ts
INNER JOIN country c
    ON ts.country_code = c.country_code
INNER JOIN world w
    ON ts.year = w.year
WHERE c.country_code = 'CHL'
'''
pd.read_sql_query(myquery, con=engine)
# Out:
#     year country_code  life_expectancy_at_birth  \
# 0   1960          CHL                    57.015
# 1   1961          CHL                    57.537
# 2   1962          CHL                    57.771
# 3   1963          CHL                    57.150
# 4   1964          CHL                    58.738
# ..   ...          ...                       ...
# 57  2017          CHL                    80.350
# 58  2018          CHL                    80.133
# 59  2019          CHL                    80.326
# 60  2020          CHL                    79.377
# 61  2021          CHL                       NaN
#
#     world_life_expectancy_at_birth
# 0                        50.894180
# 1                        52.846336
# 2                        55.208684
# 3                        55.542341
# 4                        56.034875
# ..                             ...
# 57                       72.542776
# 58                       72.784090
# 59                       72.979716
# 60                       72.243822
# 61                             NaN
#
# [62 rows x 4 columns]

# %%
#c. what regions of the world generated the most carbon dioxide emissions in 2019?
myquery = '''
SELECT c.region,
    SUM(co2_emissions) AS co2_emissions
FROM timeseries ts
INNER JOIN country c
    ON ts.country_code = c.country_code
WHERE year = 2019
GROUP BY c.region
ORDER BY co2_emissions DESC
'''
 
pd.read_sql_query(myquery, con=engine)
# Out:
#                        region  co2_emissions
# 0       Europe & Central Asia     273.807274
# 1  Middle East & North Africa     176.008097
# 2         East Asia & Pacific      94.256987
# 3   Latin America & Caribbean      68.692584
# 4          Sub-Saharan Africa      43.318399
# 5               North America      29.726128
# 6                  South Asia      10.820011

# %%
#d. What countries expereinced the greatest increases in democratic quality over the 1960-2021 time span?
myquery = '''
SELECT c.country_name_wb AS country_name, d.democracy_1960, d.democracy_2021, d.democracy_2021 - d.democracy_1960 AS democracy_diff
FROM (SELECT y2.country_code, y1.democracy_1960, y2.democracy_2021
      FROM (SELECT ts.country_code, ts.democracy AS democracy_2021
            FROM timeseries ts
            WHERE year = 2021) y2
      INNER JOIN (
        SELECT ts.country_code, ts.democracy AS democracy_1960
        FROM timeseries ts
        WHERE year = 1960) y1
        ON y2.country_code = y1.country_code) d
INNER JOIN country c
    ON d.country_code = c.country_code
ORDER BY democracy_diff DESC nulls last
'''
pd.read_sql_query(myquery, con=engine)
# Out:
#       country_name  democracy_1960  democracy_2021  democracy_diff
# 0            Spain           0.070           0.854           0.784
# 1         Portugal           0.128           0.888           0.760
# 2       Cabo Verde           0.023           0.773           0.750
# 3          Vanuatu           0.080           0.771           0.691
# 4      Timor-Leste           0.018           0.680           0.662
# ..             ...             ...             ...             ...
# 143        Lao PDR           0.276           0.135          -0.141
# 144        Somalia           0.373           0.169          -0.204
# 145          India           0.669           0.420          -0.249
# 146        Myanmar           0.421           0.107          -0.314
# 147  Venezuela, RB           0.648           0.218          -0.430
#
# [148 rows x 4 columns]

# %%
#e. By county of countries, what is the most commonly used currency in the world?
myquery = '''
SELECT c.currency_unit,
    COUNT(*) AS num_of_countries
FROM country c
GROUP BY c.currency_unit
ORDER BY num_of_countries DESC
LIMIT 10
'''
 
pd.read_sql_query(myquery, con=engine)
# Out:
#                currency_unit  num_of_countries
# 0                       Euro                24
# 1     West African CFA franc                 8
# 2                U.S. dollar                 7
# 3  Central African CFA franc                 6
# 4      East Caribbean dollar                 6
# 5          Australian dollar                 4
# 6                Swiss franc                 2
# 7       Sierra Leonean leone                 1
# 8         New Zambian kwacha                 1
# 9                    Lao kip                 1

# %%
#f. How does the average GINI index compare across income groups in 2019?
myquery = '''
SELECT
    c.income_group,
    AVG(t.gini_index) as average_gini_index
FROM
    timeseries t
JOIN
    country c ON t.country_code = c.country_code
WHERE
    t.year = 2019
GROUP BY
    c.income_group
ORDER BY
    average_gini_index DESC;
'''
pd.read_sql_query(myquery, con=engine)
# Out:
#           income_group  average_gini_index
# 0                 None                 NaN
# 1           Low income           43.900000
# 2  Upper middle income           38.145833
# 3  Lower middle income           37.420000
# 4          High income           31.731250
